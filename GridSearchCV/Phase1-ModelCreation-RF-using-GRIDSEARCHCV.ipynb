# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset, drop_first=True,dtype=int)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

grid_param={'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
            'max_features':['sqrt','log2',0], 'n_estimators':[10,100,1000]}

grid=GridSearchCV(RandomForestRegressor(), grid_param, refit=True, verbose=3, n_jobs=-1)

grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 60 fits failed out of a total of 180.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 45 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 0 instead.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 0 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.78664249 0.81223261 0.81440945 0.7936281  0.81249608 0.81422283
#         nan        nan        nan 0.80299848 0.81107814 0.81466951
#  0.78792472 0.81484531 0.81449552        nan        nan        nan
#  0.78913666 0.81271277 0.81383692 0.77980245 0.8106658  0.81397094
#         nan        nan        nan 0.7973572  0.81102072 0.8137273
#  0.7937589  0.81476961 0.81402502        nan        nan        nan]
#   warnings.warn(
# C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2', 0],
#                          'n_estimators': [10, 100, 1000]},
#              verbose=3)

# %%
y_pred=grid.predict(x_test)
all_param=grid.cv_results_
grid.best_params_
# Out:
# {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100}

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.870603096696603

# %%
table=pd.DataFrame.from_dict(all_param)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.180988      0.053839         0.007796        0.004508
# 1        0.644785      0.006480         0.028124        0.006249
# 2        7.452749      0.409284         0.321864        0.044850
# 3        0.121869      0.054485         0.012501        0.006250
# 4        0.809273      0.033434         0.035613        0.006069
# 5        7.900312      0.172733         0.300269        0.024063
# 6        0.003125      0.006249         0.000000        0.000000
# 7        0.003125      0.006249         0.000000        0.000000
# 8        0.000000      0.000000         0.000000        0.000000
# 9        0.087494      0.007657         0.003125        0.006251
# 10       0.775251      0.039607         0.031250        0.000001
# 11       8.177569      0.289958         0.278115        0.022964
# 12       0.084373      0.007653         0.003125        0.006250
# 13       0.909343      0.113705         0.034374        0.006250
# 14       7.766070      0.067297         0.256241        0.007654
# 15       0.000000      0.000000         0.000000        0.000000
# 16       0.000000      0.000000         0.000000        0.000000
# 17       0.000000      0.000000         0.000000        0.000000
# 18       0.203115      0.017115         0.003125        0.006250
# 19       1.840554      0.006262         0.028125        0.006250
# 20      18.725217      0.835840         0.286034        0.034785
# 21       0.232174      0.042509         0.009080        0.005936
# 22       2.051621      0.097363         0.028125        0.006250
# 23      19.536326      2.312408         0.271766        0.017802
# 24       0.000000      0.000000         0.000000        0.000000
# 25       0.003125      0.006250         0.000000        0.000000
# 26       0.006250      0.007654         0.000000        0.000000
# 27       0.259366      0.331238         0.000000        0.000000
# 28       0.884242      0.012670         0.031756        0.001019
# 29       9.512886      0.823550         0.345976        0.078125
# 30       0.097450      0.009097         0.006449        0.000520
# 31       1.089111      0.217170         0.055325        0.034467
# 32       8.070341      0.741846         0.245344        0.032639
# 33       0.003125      0.006250         0.000000        0.000000
# 34       0.006250      0.007654         0.000000        0.000000
# 35       0.000000      0.000000         0.000000        0.000000
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                100
# 2    squared_error               sqrt               1000
# 3    squared_error               log2                 10
# 4    squared_error               log2                100
# 5    squared_error               log2               1000
# 6    squared_error                  0                 10
# 7    squared_error                  0                100
# 8    squared_error                  0               1000
# 9     friedman_mse               sqrt                 10
# 10    friedman_mse               sqrt                100
# 11    friedman_mse               sqrt               1000
# 12    friedman_mse               log2                 10
# 13    friedman_mse               log2                100
# 14    friedman_mse               log2               1000
# 15    friedman_mse                  0                 10
# 16    friedman_mse                  0                100
# 17    friedman_mse                  0               1000
# 18  absolute_error               sqrt                 10
# 19  absolute_error               sqrt                100
# 20  absolute_error               sqrt               1000
# 21  absolute_error               log2                 10
# 22  absolute_error               log2                100
# 23  absolute_error               log2               1000
# 24  absolute_error                  0                 10
# 25  absolute_error                  0                100
# 26  absolute_error                  0               1000
# 27         poisson               sqrt                 10
# 28         poisson               sqrt                100
# 29         poisson               sqrt               1000
# 30         poisson               log2                 10
# 31         poisson               log2                100
# 32         poisson               log2               1000
# 33         poisson                  0                 10
# 34         poisson                  0                100
# 35         poisson                  0               1000
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.826008
# 1   {'criterion': 'squared_error', 'max_features':...           0.864513
# 2   {'criterion': 'squared_error', 'max_features':...           0.866886
# 3   {'criterion': 'squared_error', 'max_features':...           0.862978
# 4   {'criterion': 'squared_error', 'max_features':...           0.866230
# 5   {'criterion': 'squared_error', 'max_features':...           0.867278
# 6   {'criterion': 'squared_error', 'max_features':...                NaN
# 7   {'criterion': 'squared_error', 'max_features':...                NaN
# 8   {'criterion': 'squared_error', 'max_features':...                NaN
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.832530
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.858007
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.866729
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.841788
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.865709
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.865193
# 15  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 16  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 17  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 18  {'criterion': 'absolute_error', 'max_features'...           0.818452
# 19  {'criterion': 'absolute_error', 'max_features'...           0.859416
# 20  {'criterion': 'absolute_error', 'max_features'...           0.860531
# 21  {'criterion': 'absolute_error', 'max_features'...           0.823506
# 22  {'criterion': 'absolute_error', 'max_features'...           0.859961
# 23  {'criterion': 'absolute_error', 'max_features'...           0.861411
# 24  {'criterion': 'absolute_error', 'max_features'...                NaN
# 25  {'criterion': 'absolute_error', 'max_features'...                NaN
# 26  {'criterion': 'absolute_error', 'max_features'...                NaN
# 27  {'criterion': 'poisson', 'max_features': 'sqrt...           0.841433
# 28  {'criterion': 'poisson', 'max_features': 'sqrt...           0.865715
# 29  {'criterion': 'poisson', 'max_features': 'sqrt...           0.864910
# 30  {'criterion': 'poisson', 'max_features': 'log2...           0.853430
# 31  {'criterion': 'poisson', 'max_features': 'log2...           0.866839
# 32  {'criterion': 'poisson', 'max_features': 'log2...           0.864363
# 33  {'criterion': 'poisson', 'max_features': 0, 'n...                NaN
# 34  {'criterion': 'poisson', 'max_features': 0, 'n...                NaN
# 35  {'criterion': 'poisson', 'max_features': 0, 'n...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.761398           0.796458           0.792842
# 1            0.791434           0.806427           0.823716
# 2            0.792421           0.809432           0.830354
# 3            0.771586           0.782555           0.795772
# 4            0.787850           0.807632           0.829079
# 5            0.792852           0.810214           0.830001
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9            0.787613           0.797367           0.826556
# 10           0.787895           0.813886           0.825117
# 11           0.794197           0.811078           0.829421
# 12           0.751715           0.780247           0.814657
# 13           0.797055           0.812858           0.827982
# 14           0.794015           0.810604           0.830965
# 15                NaN                NaN                NaN
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18           0.778091           0.770917           0.812939
# 19           0.798400           0.807760           0.828804
# 20           0.797066           0.810486           0.828888
# 21           0.758301           0.762270           0.807067
# 22           0.787921           0.814265           0.822576
# 23           0.796527           0.809852           0.828150
# 24                NaN                NaN                NaN
# 25                NaN                NaN                NaN
# 26                NaN                NaN                NaN
# 27           0.771610           0.799639           0.818965
# 28           0.791168           0.803746           0.836252
# 29           0.794380           0.810168           0.828820
# 30           0.762004           0.798784           0.806358
# 31           0.799077           0.810349           0.828902
# 32           0.793441           0.812553           0.828554
# 33                NaN                NaN                NaN
# 34                NaN                NaN                NaN
# 35                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.756506         0.786642        0.025416               23
# 1            0.775073         0.812233        0.030699               13
# 2            0.772955         0.814409        0.032356                5
# 3            0.755249         0.793628        0.037136               20
# 4            0.771689         0.812496        0.033041               12
# 5            0.770769         0.814223        0.032939                6
# 6                 NaN              NaN             NaN               25
# 7                 NaN              NaN             NaN               25
# 8                 NaN              NaN             NaN               25
# 9            0.770927         0.802998        0.023341               17
# 10           0.770486         0.811078        0.030307               14
# 11           0.771923         0.814670        0.032209                3
# 12           0.751218         0.787925        0.035590               22
# 13           0.770623         0.814845        0.031735                1
# 14           0.771700         0.814496        0.031961                4
# 15                NaN              NaN             NaN               25
# 16                NaN              NaN             NaN               25
# 17                NaN              NaN             NaN               25
# 18           0.765284         0.789137        0.022130               21
# 19           0.769184         0.812713        0.030214               11
# 20           0.772214         0.813837        0.029772                9
# 21           0.747867         0.779802        0.029809               24
# 22           0.768607         0.810666        0.031212               16
# 23           0.773914         0.813971        0.029589                8
# 24                NaN              NaN             NaN               25
# 25                NaN              NaN             NaN               25
# 26                NaN              NaN             NaN               25
# 27           0.755139         0.797357        0.031177               18
# 28           0.758222         0.811021        0.037048               15
# 29           0.770359         0.813727        0.031985               10
# 30           0.748219         0.793759        0.036951               19
# 31           0.768682         0.814770        0.032560                2
# 32           0.771215         0.814025        0.031634                7
# 33                NaN              NaN             NaN               25
# 34                NaN              NaN             NaN               25
# 35                NaN              NaN             NaN               25

# %%
import pickle
filename="FINAL_MODEL_GRIDSEARCHCV_RF.sav"
pickle.dump(grid,open(filename, 'wb'))
load_model=pickle.load(open("FINAL_MODEL_GRIDSEARCHCV_RF.sav", 'rb'))
result=load_model.predict([[1,2,3,4,5]])
result
# Out:
# array([46445.8344988])
