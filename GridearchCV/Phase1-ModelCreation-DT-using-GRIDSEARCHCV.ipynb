# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset, drop_first=True,dtype=int)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

grid_param={'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
            'splitter':['best', 'random'], 'max_features':['sqrt','log2',0]}

grid=GridSearchCV(DecisionTreeRegressor(), grid_param, refit=True, verbose=3, n_jobs=-1)

grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 14 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 0 instead.
#
# --------------------------------------------------------------------------------
# 26 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 0 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\DEEPAK\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.62613821 0.52474069 0.65903147 0.54171749        nan        nan
#  0.66534872 0.60601591 0.65892752 0.56560722        nan        nan
#  0.59194885 0.57645818 0.64389275 0.64297658        nan        nan
#  0.58268553 0.58089828 0.63890723 0.5619692         nan        nan]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2', 0],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
all_param=grid.cv_results_
grid.best_params_
y_pred=grid.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.6702859956853358

# %%
table=pd.DataFrame.from_dict(all_param)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.040624      0.027243         0.009375        0.007655
# 1        0.006249      0.007654         0.006250        0.007655
# 2        0.021875      0.007656         0.000000        0.000000
# 3        0.009375      0.007655         0.003125        0.006251
# 4        0.003125      0.006249         0.000000        0.000000
# 5        0.000000      0.000000         0.000000        0.000000
# 6        0.009375      0.007655         0.000000        0.000000
# 7        0.012500      0.006250         0.003125        0.006250
# 8        0.012500      0.006250         0.003125        0.006250
# 9        0.009375      0.007654         0.006250        0.007654
# 10       0.000000      0.000000         0.000000        0.000000
# 11       0.000000      0.000000         0.000000        0.000000
# 12       0.031250      0.000005         0.000000        0.000000
# 13       0.021874      0.007655         0.000000        0.000000
# 14       0.031248      0.000002         0.000000        0.000000
# 15       0.012500      0.011692         0.006250        0.007655
# 16       0.003125      0.006250         0.000000        0.000000
# 17       0.000000      0.000000         0.000000        0.000000
# 18       0.028120      0.041221         0.009376        0.007655
# 19       0.024995      0.035078         0.006251        0.007656
# 20       0.024999      0.042617         0.006249        0.007653
# 21       0.006246      0.007650         0.006251        0.007656
# 22       0.000000      0.000000         0.000000        0.000000
# 23       0.000000      0.000000         0.000000        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error                  0           best
# 5    squared_error                  0         random
# 6     friedman_mse               sqrt           best
# 7     friedman_mse               sqrt         random
# 8     friedman_mse               log2           best
# 9     friedman_mse               log2         random
# 10    friedman_mse                  0           best
# 11    friedman_mse                  0         random
# 12  absolute_error               sqrt           best
# 13  absolute_error               sqrt         random
# 14  absolute_error               log2           best
# 15  absolute_error               log2         random
# 16  absolute_error                  0           best
# 17  absolute_error                  0         random
# 18         poisson               sqrt           best
# 19         poisson               sqrt         random
# 20         poisson               log2           best
# 21         poisson               log2         random
# 22         poisson                  0           best
# 23         poisson                  0         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.676061
# 1   {'criterion': 'squared_error', 'max_features':...           0.545636
# 2   {'criterion': 'squared_error', 'max_features':...           0.756855
# 3   {'criterion': 'squared_error', 'max_features':...           0.641674
# 4   {'criterion': 'squared_error', 'max_features':...                NaN
# 5   {'criterion': 'squared_error', 'max_features':...                NaN
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.749331
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.665641
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.696623
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.596451
# 10  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 11  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 12  {'criterion': 'absolute_error', 'max_features'...           0.670237
# 13  {'criterion': 'absolute_error', 'max_features'...           0.738130
# 14  {'criterion': 'absolute_error', 'max_features'...           0.749243
# 15  {'criterion': 'absolute_error', 'max_features'...           0.703814
# 16  {'criterion': 'absolute_error', 'max_features'...                NaN
# 17  {'criterion': 'absolute_error', 'max_features'...                NaN
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.653863
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.532499
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.706738
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.685064
# 22  {'criterion': 'poisson', 'max_features': 0, 's...                NaN
# 23  {'criterion': 'poisson', 'max_features': 0, 's...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.656256           0.642840           0.520880
# 1            0.536233           0.623259           0.526029
# 2            0.565089           0.658573           0.656178
# 3            0.452795           0.623617           0.366981
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6            0.677851           0.621435           0.656534
# 7            0.609132           0.529505           0.658713
# 8            0.648022           0.684505           0.613488
# 9            0.519368           0.601566           0.508207
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12           0.566055           0.487256           0.634018
# 13           0.449813           0.576870           0.490292
# 14           0.646538           0.694288           0.568711
# 15           0.499502           0.657562           0.670287
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18           0.532932           0.736717           0.559019
# 19           0.596911           0.452357           0.685352
# 20           0.661992           0.626483           0.560147
# 21           0.475563           0.567269           0.672478
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.634654         0.626138        0.054461                7
# 1            0.392547         0.524741        0.074500               16
# 2            0.658462         0.659031        0.060669                2
# 3            0.623521         0.541717        0.111203               15
# 4                 NaN              NaN             NaN               17
# 5                 NaN              NaN             NaN               17
# 6            0.621593         0.665349        0.047181                1
# 7            0.567088         0.606016        0.052366                8
# 8            0.652000         0.658928        0.029349                3
# 9            0.602444         0.565607        0.042507               13
# 10                NaN              NaN             NaN               17
# 11                NaN              NaN             NaN               17
# 12           0.602179         0.591949        0.062665                9
# 13           0.627186         0.576458        0.102152               12
# 14           0.560684         0.643893        0.072417                4
# 15           0.683718         0.642977        0.073355                5
# 16                NaN              NaN             NaN               17
# 17                NaN              NaN             NaN               17
# 18           0.430897         0.582686        0.104754               10
# 19           0.637373         0.580898        0.081513               11
# 20           0.639175         0.638907        0.047941                6
# 21           0.409473         0.561969        0.107809               14
# 22                NaN              NaN             NaN               17
# 23                NaN              NaN             NaN               17

# %%
import pickle
filename="FINAL_MODEL_GRIDSEARCHCV_DT.sav"
pickle.dump(grid,open(filename, 'wb'))
load_model=pickle.load(open("FINAL_MODEL_GRIDSEARCHCV_DT.sav", 'rb'))
result=load_model.predict([[1,2,3,4,5]])
result
# Out:
# array([48549.17835])
